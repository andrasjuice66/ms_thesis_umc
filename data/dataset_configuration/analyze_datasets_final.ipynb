# %% [markdown]
# # Dataset Analysis with Configurable Train / Val / Test Split

# %%
# ------------------------------------------------------------
# CONFIG – edit only the variables below
# ------------------------------------------------------------
TRAIN_DATASETS      = ['camcan', 'dallas_lifespan', 'npc', 'nimh_rv', 'oasis3', 'pangen', 'sald', 'corr', 'narratives', 'aomic_id1000']  # example
TEST_DATASETS       = ['ixi', 'boldvar']                    # example

VAL_FRACTION        = 0.20   # 0.10 → 10 % of TRAIN becomes VAL
RANDOM_STATE        = 42     # reproducible shuffles
DROP_OTHER_DATASETS = True   # ignore rows from datasets not listed

# --- global analysis parameters -------------------------------------------
AGE_MIN, AGE_MAX = 20, 80
MODALITIES       = ['t1', 't2', 'flair']

# --- minimal subset parameters (hyper-parameter tuning) -------------------
SUBSET_SEX            = 'male'   # 'male' or 'female'
SUBSET_MODALITY       = 't1'     # any value from MODALITIES
SUBSET_AGE_MIN, SUBSET_AGE_MAX = 30, 40  # inclusive range

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
import itertools, warnings, uuid, sys
from sklearn.model_selection import train_test_split
from pathlib import Path
import os

warnings.filterwarnings('ignore')
sns.set(style='whitegrid', context='notebook')

# define labels directory as a sibling to this script's dir
LABEL_DIR = Path('..') / 'labels'
LABEL_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ------------------------------------------------------------
# Helper functions
# ------------------------------------------------------------
def clean_df(raw: pd.DataFrame) -> pd.DataFrame:
    """Standardise column names & values, drop unusable rows, and create 5-year age bins."""
    df = raw.copy()
    df.columns = df.columns.str.strip().str.lower()

    # Convert age to numeric, coerce errors to NaN, round and convert to Int64 nullable integer
    df['age'] = pd.to_numeric(df['age'], errors='coerce').round(0)
    df = df.dropna(subset=['age'])
    df['age'] = df['age'].astype('Int64')

    # Standardize sex column
    df['sex'] = (df['sex'].astype(str).str.lower().str.strip()
                   .map({'m':'male','male':'male','1':'male',
                         'f':'female','female':'female','2':'female'}))

    # Extract modality values
    df['modality'] = (df['modality'].astype(str).str.lower()
                        .str.extract('(t1|t2|flair)', expand=False))

    # Drop rows with missing sex or modality
    df = df.dropna(subset=['sex', 'modality'])

    # Filter rows by age range
    df = df.query('@AGE_MIN <= age <= @AGE_MAX')

    # Create 5-year bins for age with aligned bins and labels
    bins = range(AGE_MIN, AGE_MAX + 5, 5)
    labels = [f"{i}-{i+4}" for i in range(AGE_MIN, AGE_MAX, 5)]
    df['5_year_age_bin'] = pd.cut(df['age'], bins=bins, right=False, labels=labels)

    return df

def coverage_report(df: pd.DataFrame, title: str = ''):
    """Report coverage of all (age_bin, sex, modality) combos."""
    df2 = df.copy()
    # integer age bins
    df2['age_bin'] = df2['age'].astype(int)
    # expected combinations
    all_combos = set(itertools.product(range(AGE_MIN, AGE_MAX+1), ['male','female'], MODALITIES))
    # observed combinations
    present = set(zip(df2['age_bin'], df2['sex'], df2['modality']))
    missing = sorted(all_combos - present)
    print(f'=== {title or "Dataset"} ===')
    print(f'Expected combinations : {len(all_combos)}')
    print(f'Observed combinations : {len(present)}')
    print(f'Missing combinations  : {len(missing)}\n')
    if missing:
        display(pd.DataFrame(missing, columns=['age','sex','modality']))
    # one sample per combo
    subset = (df2.groupby(['age_bin','sex','modality'], group_keys=False)
                   .sample(n=1, random_state=42)
                   .reset_index(drop=True))
    subset = subset.drop(columns=['age_bin'])
    return subset

def quick_plots(df: pd.DataFrame, title: str = ''):
    print(f'\n### {title} – shape: {df.shape}\n')
    display(df.head())
    fig, axes = plt.subplots(1, 3, figsize=(18,4))
    sns.countplot(x='modality', data=df, ax=axes[0]); axes[0].set_title('Modality')
    sns.countplot(x='sex',      data=df, ax=axes[1]); axes[1].set_title('Sex')
    sns.histplot(df['age'], bins=20, kde=True, ax=axes[2]); axes[2].set_title('Age')
    plt.suptitle(title); plt.tight_layout(); plt.show()
    for col in ['modality', 'sex']:
        g = sns.catplot(data=df, x=col, col='dataset', kind='count', col_wrap=4, sharey=False)
        g.fig.suptitle(f'{col.capitalize()} distribution per dataset', y=1.02)
        plt.show()
    g = sns.displot(data=df, x='age', col='dataset', bins=20, col_wrap=4, kde=True)
    g.fig.suptitle('Age distribution per dataset', y=1.02)
    plt.show()

# %%
# ----------------- Missing-data & count heat-map helpers -----------------
import numpy as np, matplotlib.pyplot as plt, seaborn as sns

def plot_missing_matrix(df: pd.DataFrame,
                        title: str = '',
                        *, group_by=1,
                        save_as: str | None = None,
                        cmap: str = 'binary'):
    """
    Visualise coverage as a white/black matrix.
    """

    ages   = list(range(AGE_MIN, AGE_MAX + 1, group_by))
    combos = [(m, s) for m in MODALITIES for s in ['male', 'female']]
    mat    = np.ones((len(combos), len(ages)), dtype=int)

    present = set(zip(df['age'], df['sex'], df['modality']))

    for r, (mod, sex) in enumerate(combos):
        for c, age in enumerate(ages):
            if all((a, sex, mod) not in present
                   for a in range(age, min(age + group_by, AGE_MAX + 1))):
                mat[r, c] = 0

    fig_h = max(3, 0.6 * len(combos))
    plt.figure(figsize=(18, fig_h))
    sns.heatmap(mat,
                cmap=cmap,
                cbar=False,
                xticklabels=ages,
                yticklabels=[f'{m.upper()} – {sex.capitalize()}' for m, sex in combos])

    plt.title(f'{title}\nblack = present, white = missing', fontsize=14)
    plt.xlabel('Age')
    plt.ylabel('Modality / Sex')
    plt.xticks(rotation=90, fontsize=8)
    plt.yticks(rotation=0)
    plt.tight_layout()

    if save_as:
        plt.savefig(save_as, dpi=150)
    plt.show()

def plot_count_heatmap(df: pd.DataFrame,
                       title: str = '',
                       *,
                       group_by: int = 1,        # age bin width (years)
                       cmap: str   = 'YlGnBu',
                       log_scale: bool = False,
                       save_as: str | None = None):
    

    needed = {'age', 'sex', 'modality'}
    if not needed.issubset(df.columns):
        raise ValueError(f'DataFrame must contain {needed}')

    present = df.copy()
    present['age_bin'] = (present['age'] // group_by) * group_by
    ages   = list(range(AGE_MIN, AGE_MAX + 1, group_by))
    combos = [(m, s) for m in MODALITIES for s in ['male', 'female']]

    mat = np.zeros((len(combos), len(ages)), dtype=int)
    for r, (mod, sex) in enumerate(combos):
        sub = present[(present['modality'] == mod) & (present['sex'] == sex)]
        counts = sub.groupby('age_bin').size()
        for c, age in enumerate(ages):
            mat[r, c] = counts.get(age, 0)

    plot_mat = np.log1p(mat) if log_scale else mat
    cbar_lbl = 'logₑ(1 + count)' if log_scale else 'count'
    
    fig_h = max(3, 0.6 * len(combos))
    plt.figure(figsize=(18, fig_h))
    sns.heatmap(plot_mat,
                cmap=cmap,
                annot=True,
                fmt='.0f',
                linewidths=.5,
                cbar_kws={'label': cbar_lbl},
                xticklabels=ages,
                yticklabels=[f'{m.upper()} – {s.capitalize()}' for m, s in combos])

    plt.title(f'{title}\\ncell value = number of images', fontsize=14)
    plt.xlabel('Age')
    plt.ylabel('Modality / Sex')
    plt.xticks(rotation=90, fontsize=8)
    plt.yticks(rotation=0)
    plt.tight_layout()

    if save_as:
        plt.savefig(save_as, dpi=150)
    plt.show()

# %%
# ------------------------------------------------------------
# Load Excel and concatenate all sheets
# ------------------------------------------------------------
EXCEL_FILE = 'all_datasets_segmented_npy.xlsx'  # change path if needed

sheets = pd.read_excel(EXCEL_FILE, sheet_name=None)
df_list = []
for name, sheet in sheets.items():
    if 'dataset' not in sheet.columns or sheet['dataset'].isna().all():
        sheet['dataset'] = name
    df_list.append(sheet)

df_all = pd.concat(df_list, ignore_index=True)
df_all = clean_df(df_all)
print('Loaded & cleaned data →', df_all.shape)
df_all.to_csv('age_binned_data.csv')
# Out:
# Loaded & cleaned data → (9089, 7)

# %%
nimhrv_filenames = [r"*HighResHippo*"]  # Regex for substring match

oasis_filenames = [
    r"*sub-OAS31103_ses-d0170_run-01_T1w*",
    r"*sub-OAS30516_ses-d0225_run-01_T1w*",
    r"*sub-OAS30062_ses-d0087_run-01_T1w*",
    r"*sub-OAS30558_ses-d0061_run-01_T1w*",
    r"*sub-OAS30472_ses-d0058_run-01_T1w*",
    r"*sub-OAS30106_ses-d2982_run-01_T1w*",
    r"*sub-OAS30803_ses-d0086_run-01_T1w*",
    r"*sub-OAS30367_ses-d0055_run-01_T1w*",
    r"*sub-OAS30660_ses-d0087_run-01_T1w*",
    r"*sub-OAS30032_ses-d0262_run-01_T1w*",
    r"*sub-OAS30444_ses-d0001_run-04_T1w*",
    r"*sub-OAS30059_ses-d0230_run-01_T1w*",
    r"*sub-OAS30455_ses-d0171_run-01_T1w*",
    r"*sub-OAS30969_ses-d3306_run-01_T1w*",
    r"*sub-OAS30103_ses-d3306_run-01_T1w*",
    r"*sub-OAS31072_ses-d0833_run-01_T1w*",
    r"*sub-OAS30059_ses-d0230_run-04_T1w*",
    r"*sub-OAS30444_ses-d0001_run-01_T1w*",
    r"*sub-OAS30297_ses-d0105_run-01_T1w*",
    r"*sub-OAS30689_ses-d0282_run-01_T1w*",
    r"*sub-OAS30181_ses-d0129_run-01_T1w*",
    r"*sub-OAS30785_ses-d0768_run-01_T1w*",
    r"*sub-OAS30365_ses-d5600_run-01_T1w*",
    r"*sub-OAS30558_ses-d0155_run-01_T1w*",
    r"*sub-OAS30059_ses-d0230_run-01_T1w*",
    r"*sub-OAS30459_ses-d0078_run-01_T1w*"  # .nii.gz or any suffix
]

REMOVE_PATTERNS = oasis_filenames + nimhrv_filenames

# %%
# ------------------------------------------------------------
# Remove images with certain names or patterns
# ------------------------------------------------------------
import fnmatch

# Determine which column to use for filtering
col = 'image_path'
print("DataFrame columns:", df_all.columns)
print("\nSample filenames:")
if 'image_path' in df_all.columns:
    print(df_all['image_path'].head())
print("\nDataFrame shape before removal:", df_all.shape)

if col:
    mask = df_all[col].astype(str).apply(
        lambda x: any(fnmatch.fnmatch(x, p) for p in REMOVE_PATTERNS)
    )
else:
    mask = pd.Series(False, index=df_all.index)

if mask.any():
    print(f"Removing {mask.sum()} rows matching patterns: {REMOVE_PATTERNS}")
    df_all = df_all.loc[~mask].copy()
else:
    print('No rows removed; no filename or image_name patterns matched.')
# Out:
# DataFrame columns: Index(['subject_id', 'image_path', 'sex', 'age', 'modality', 'dataset',
#        '5_year_age_bin'],
#       dtype='object')
#
# Sample filenames:
# 0    IXI/IXI002-Guys-0828-T1.nii.npy
# 1    IXI/IXI002-Guys-0828-T2.nii.npy
# 2      IXI/IXI012-HH-1211-T1.nii.npy
# 3      IXI/IXI012-HH-1211-T2.nii.npy
# 4      IXI/IXI013-HH-1212-T1.nii.npy
# Name: image_path, dtype: object
#
# DataFrame shape before removal: (9089, 7)
# Removing 21 rows matching patterns: ['*sub-OAS31103_ses-d0170_run-01_T1w*', '*sub-OAS30516_ses-d0225_run-01_T1w*', '*sub-OAS30062_ses-d0087_run-01_T1w*', '*sub-OAS30558_ses-d0061_run-01_T1w*', '*sub-OAS30472_ses-d0058_run-01_T1w*', '*sub-OAS30106_ses-d2982_run-01_T1w*', '*sub-OAS30803_ses-d0086_run-01_T1w*', '*sub-OAS30367_ses-d0055_run-01_T1w*', '*sub-OAS30660_ses-d0087_run-01_T1w*', '*sub-OAS30032_ses-d0262_run-01_T1w*', '*sub-OAS30444_ses-d0001_run-04_T1w*', '*sub-OAS30059_ses-d0230_run-01_T1w*', '*sub-OAS30455_ses-d0171_run-01_T1w*', '*sub-OAS30969_ses-d3306_run-01_T1w*', '*sub-OAS30103_ses-d3306_run-01_T1w*', '*sub-OAS31072_ses-d0833_run-01_T1w*', '*sub-OAS30059_ses-d0230_run-04_T1w*', '*sub-OAS30444_ses-d0001_run-01_T1w*', '*sub-OAS30297_ses-d0105_run-01_T1w*', '*sub-OAS30689_ses-d0282_run-01_T1w*', '*sub-OAS30181_ses-d0129_run-01_T1w*', '*sub-OAS30785_ses-d0768_run-01_T1w*', '*sub-OAS30365_ses-d5600_run-01_T1w*', '*sub-OAS30558_ses-d0155_run-01_T1w*', '*sub-OAS30059_ses-d0230_run-01_T1w*', '*sub-OAS30459_ses-d0078_run-01_T1w*', '*HighResHippo*']

# %% [markdown]
# ### Train / Val / Test Split Summary

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# ------------------------------------------------------------------
# helper (same as before – put it somewhere once)
# ------------------------------------------------------------------
def cap_per_combo(df: pd.DataFrame,
                  combo_cols     = ['modality', 'sex', '5_year_age_bin'],
                  max_per_combo  = 5,
                  random_state   = 42):
    """
    Return (kept_df, overflow_df) where kept_df has at most
    `max_per_combo` rows per unique combo in `combo_cols`.
    """
    keep, overflow = [], []
    for _, g in df.groupby(combo_cols, group_keys=False):
        if len(g) > max_per_combo:
            keep.append(g.sample(max_per_combo, random_state=random_state))
            overflow.append(g.drop(keep[-1].index))
        else:
            keep.append(g)
    kept     = pd.concat(keep,     ignore_index=True)
    overflow = pd.concat(overflow, ignore_index=True) if overflow else \
               pd.DataFrame(columns=df.columns)
    return kept, overflow

def stratified_train_val_split(df: pd.DataFrame, stratify_cols: list, val_fraction: float, random_state: int):
    """
    Perform stratified train/validation split on df based on stratify_cols.
    Groups with fewer than 2 samples are kept entirely in the training set.
    """
    group_counts = df.groupby(stratify_cols).size()
    valid_groups = group_counts[group_counts >= 2].index
    mask_valid = df.set_index(stratify_cols).index.isin(valid_groups)
    df_valid_groups = df[mask_valid]
    df_rare_groups = df[~mask_valid]

    df_train, df_val = train_test_split(
        df_valid_groups,
        test_size=val_fraction,
        random_state=random_state,
        stratify=df_valid_groups[stratify_cols]
    )

    df_train = pd.concat([df_train, df_rare_groups], ignore_index=True)
    return df_train.reset_index(drop=True), df_val.reset_index(drop=True)

# ------------------------------------------------------------
# Build explicit TRAIN / VAL / TEST partitions
# ------------------------------------------------------------
train_lower = [d.lower() for d in TRAIN_DATASETS]
test_lower  = [d.lower() for d in TEST_DATASETS]
if set(train_lower) & set(test_lower):
    raise ValueError('A dataset appears in both TRAIN_DATASETS and TEST_DATASETS')

all_datasets_lower = df_all['dataset'].str.lower()
is_train = all_datasets_lower.isin(train_lower)
is_test  = all_datasets_lower.isin(test_lower)

if DROP_OTHER_DATASETS:
    used_mask = is_train | is_test
    dropped   = df_all.loc[~used_mask, 'dataset'].unique()
    if len(dropped):
        print(' ⚠️  Dropping datasets (not in either list):', dropped)
    df_all   = df_all[used_mask].copy()
    is_train = is_train.loc[df_all.index]
    is_test  = is_test .loc[df_all.index]

df_train_full = df_all[is_train].copy()
df_test       = df_all[is_test ].copy()

if VAL_FRACTION > 0 and not df_train_full.empty:
    df_train, df_val = stratified_train_val_split(
        df_train_full,
        stratify_cols=['modality', 'sex', '5_year_age_bin'],
        val_fraction=VAL_FRACTION,
        random_state=RANDOM_STATE
    )
else:
    df_train = df_train_full.copy()
    df_val   = pd.DataFrame(columns=df_all.columns)
# ------------------------------------------------------------------
# apply the cap to the *already-created* validation set
# ------------------------------------------------------------------
df_val, val_overflow = cap_per_combo(
    df_val,
    combo_cols    = ['modality', 'sex', 'age'],
    max_per_combo = 5,
    random_state  = RANDOM_STATE
)

# move the overflow rows into training (or drop them if you prefer)
df_train = pd.concat([df_train, val_overflow], ignore_index=True)

# Check for overlapping subjects between train and validation sets
if not df_val.empty:
    train_subjects = set(df_train['subject_id'])
    val_subjects = set(df_val['subject_id'])
    overlap = train_subjects & val_subjects

    print(f"Number of unique subjects in training set: {len(train_subjects)}")
    print(f"Number of unique subjects in validation set: {len(val_subjects)}")
    print(f"Number of overlapping subjects: {len(overlap)}")

    if overlap:
        print("\nOverlapping subjects:")
        for subject in sorted(overlap):
            print(f"- {subject}")
else:
    print("Validation set is empty - no overlap check needed")

print(f'Total rows used : {len(df_all):,}')
print(f'  TRAIN : {len(df_train):,}')
print(f'  VAL   : {len(df_val):,}')
print(f'  TEST  : {len(df_test):,}')
# Out:
# Number of unique subjects in training set: 4755
# Number of unique subjects in validation set: 895
# Number of overlapping subjects: 594
#
# Overlapping subjects:
# - sub-01
# - sub-02
# - sub-04
# - sub-07
# - sub-1003
# - sub-1007
# - sub-101
# - sub-1084
# - sub-11
# - sub-1141
# - sub-1165
# - sub-1172
# - sub-1199
# - sub-12
# - sub-1245
# - sub-1251
# - sub-1309
# - sub-133
# - sub-140
# - sub-1402
# - sub-1439
# - sub-1452
# - sub-1457
# - sub-1467
# - sub-147
# - sub-149
# - sub-15
# - sub-155
# - sub-158
# - sub-1615
# - sub-1626
# - sub-1685
# - sub-174
# - sub-1751
# - sub-1796
# - sub-1860
# - sub-1864
# - sub-1869
# - sub-1874
# - sub-19
# - sub-192
# - sub-1926
# - sub-194
# - sub-1978
# - sub-208
# - sub-2085
# - sub-2117
# - sub-2127
# - sub-2205
# - sub-2248
# - sub-2327
# - sub-25
# - sub-27
# - sub-2740
# - sub-2743
# - sub-2790
# - sub-2813
# - sub-2889
# - sub-2893
# - sub-295
# - sub-2976
# - sub-3053
# - sub-31
# - sub-3102
# - sub-3131
# - sub-3146
# - sub-326
# - sub-3331
# - sub-3334
# - sub-34
# - sub-3457
# - sub-3462
# - sub-361
# - sub-3737
# - sub-3799
# - sub-381
# - sub-3846
# - sub-39
# - sub-4033
# - sub-4129
# - sub-4265
# - sub-43
# - sub-4315
# - sub-4394
# - sub-4488
# - sub-45
# - sub-4581
# - sub-4613
# - sub-4659
# - sub-4664
# - sub-4684
# - sub-47
# - sub-4727
# - sub-4743
# - sub-4749
# - sub-48
# - sub-49
# - sub-53
# - sub-543
# - sub-562
# - sub-58
# - sub-580
# - sub-587
# - sub-595
# - sub-609
# - sub-61
# - sub-66
# - sub-665
# - sub-688
# - sub-770
# - sub-772
# - sub-799
# - sub-812
# - sub-817
# - sub-818
# - sub-823
# - sub-832
# - sub-836
# - sub-841
# - sub-886
# - sub-898
# - sub-929
# - sub-974
# - sub-978
# - sub-989
# - sub-CC110045
# - sub-CC110098
# - sub-CC120218
# - sub-CC120640
# - sub-CC120764
# - sub-CC210088
# - sub-CC210124
# - sub-CC210148
# - sub-CC210304
# - sub-CC210526
# - sub-CC210657
# - sub-CC220132
# - sub-CC220284
# - sub-CC220419
# - sub-CC220526
# - sub-CC220635
# - sub-CC220806
# - sub-CC220843
# - sub-CC220901
# - sub-CC221033
# - sub-CC221336
# - sub-CC221487
# - sub-CC221565
# - sub-CC221733
# - sub-CC221740
# - sub-CC221755
# - sub-CC221886
# - sub-CC221954
# - sub-CC222120
# - sub-CC222258
# - sub-CC222264
# - sub-CC222555
# - sub-CC222652
# - sub-CC222797
# - sub-CC223115
# - sub-CC310052
# - sub-CC310086
# - sub-CC310135
# - sub-CC310214
# - sub-CC310414
# - sub-CC310450
# - sub-CC310463
# - sub-CC320107
# - sub-CC320160
# - sub-CC320202
# - sub-CC320206
# - sub-CC320218
# - sub-CC320269
# - sub-CC320297
# - sub-CC320336
# - sub-CC320417
# - sub-CC320448
# - sub-CC320500
# - sub-CC320568
# - sub-CC320608
# - sub-CC320661
# - sub-CC320687
# - sub-CC320698
# - sub-CC320904
# - sub-CC321053
# - sub-CC321069
# - sub-CC321073
# - sub-CC321107
# - sub-CC321203
# - sub-CC321464
# - sub-CC321544
# - sub-CC321557
# - sub-CC321880
# - sub-CC321976
# - sub-CC410040
# - sub-CC410097
# - sub-CC410129
# - sub-CC410284
# - sub-CC410289
# - sub-CC410390
# - sub-CC420089
# - sub-CC420091
# - sub-CC420157
# - sub-CC420198
# - sub-CC420202
# - sub-CC420226
# - sub-CC420229
# - sub-CC420231
# - sub-CC420241
# - sub-CC420261
# - sub-CC420383
# - sub-CC420396
# - sub-CC420435
# - sub-CC420587
# - sub-CC420589
# - sub-CC420729
# - sub-CC510226
# - sub-CC510242
# - sub-CC510256
# - sub-CC510259
# - sub-CC510342
# - sub-CC510354
# - sub-CC510433
# - sub-CC510473
# - sub-CC510474
# - sub-CC510483
# - sub-CC510551
# - sub-CC510568
# - sub-CC510639
# - sub-CC512003
# - sub-CC520197
# - sub-CC520209
# - sub-CC520215
# - sub-CC520253
# - sub-CC520477
# - sub-CC520503
# - sub-CC520552
# - sub-CC520584
# - sub-CC520585
# - sub-CC520597
# - sub-CC520624
# - sub-CC520775
# - sub-CC610028
# - sub-CC610061
# - sub-CC610101
# - sub-CC610227
# - sub-CC610405
# - sub-CC610508
# - sub-CC610671
# - sub-CC620073
# - sub-CC620118
# - sub-CC620129
# - sub-CC620193
# - sub-CC620262
# - sub-CC620284
# - sub-CC620354
# - sub-CC620359
# - sub-CC620451
# - sub-CC620490
# - sub-CC620515
# - sub-CC620572
# - sub-CC620619
# - sub-CC620720
# - sub-CC620885
# - sub-CC621080
# - sub-CC621642
# - sub-CC710214
# - sub-CC720180
# - sub-CC720188
# - sub-CC721052
# - sub-CC721107
# - sub-CC721292
# - sub-CC721585
# - sub-OAS30001
# - sub-OAS30008
# - sub-OAS30011
# - sub-OAS30014
# - sub-OAS30017
# - sub-OAS30030
# - sub-OAS30036
# - sub-OAS30039
# - sub-OAS30042
# - sub-OAS30044
# - sub-OAS30067
# - sub-OAS30073
# - sub-OAS30080
# - sub-OAS30082
# - sub-OAS30105
# - sub-OAS30115
# - sub-OAS30129
# - sub-OAS30134
# - sub-OAS30141
# - sub-OAS30142
# - sub-OAS30167
# - sub-OAS30174
# - sub-OAS30182
# - sub-OAS30183
# - sub-OAS30187
# - sub-OAS30189
# - sub-OAS30191
# - sub-OAS30200
# - sub-OAS30219
# - sub-OAS30232
# - sub-OAS30251
# - sub-OAS30264
# - sub-OAS30270
# - sub-OAS30272
# - sub-OAS30277
# - sub-OAS30280
# - sub-OAS30283
# - sub-OAS30289
# - sub-OAS30299
# - sub-OAS30306
# - sub-OAS30309
# - sub-OAS30337
# - sub-OAS30348
# - sub-OAS30349
# - sub-OAS30353
# - sub-OAS30368
# - sub-OAS30382
# - sub-OAS30392
# - sub-OAS30395
# - sub-OAS30406
# - sub-OAS30429
# - sub-OAS30438
# - sub-OAS30461
# - sub-OAS30462
# - sub-OAS30483
# - sub-OAS30484
# - sub-OAS30486
# - sub-OAS30508
# - sub-OAS30514
# - sub-OAS30535
# - sub-OAS30537
# - sub-OAS30538
# - sub-OAS30547
# - sub-OAS30559
# - sub-OAS30603
# - sub-OAS30620
# - sub-OAS30626
# - sub-OAS30636
# - sub-OAS30644
# - sub-OAS30658
# - sub-OAS30668
# - sub-OAS30674
# - sub-OAS30679
# - sub-OAS30683
# - sub-OAS30690
# - sub-OAS30693
# - sub-OAS30710
# - sub-OAS30715
# - sub-OAS30723
# - sub-OAS30728
# - sub-OAS30729
# - sub-OAS30731
# - sub-OAS30735
# - sub-OAS30747
# - sub-OAS30757
# - sub-OAS30759
# - sub-OAS30764
# - sub-OAS30766
# - sub-OAS30769
# - sub-OAS30772
# - sub-OAS30800
# - sub-OAS30801
# - sub-OAS30813
# - sub-OAS30824
# - sub-OAS30835
# - sub-OAS30844
# - sub-OAS30846
# - sub-OAS30857
# - sub-OAS30861
# - sub-OAS30871
# - sub-OAS30875
# - sub-OAS30879
# - sub-OAS30890
# - sub-OAS30904
# - sub-OAS30917
# - sub-OAS30922
# - sub-OAS30938
# - sub-OAS30943
# - sub-OAS30945
# - sub-OAS30958
# - sub-OAS30967
# - sub-OAS30977
# - sub-OAS30980
# - sub-OAS30986
# - sub-OAS30992
# - sub-OAS30995
# - sub-OAS30997
# - sub-OAS31017
# - sub-OAS31018
# - sub-OAS31020
# - sub-OAS31022
# - sub-OAS31025
# - sub-OAS31028
# - sub-OAS31034
# - sub-OAS31057
# - sub-OAS31066
# - sub-OAS31069
# - sub-OAS31073
# - sub-OAS31087
# - sub-OAS31113
# - sub-OAS31114
# - sub-OAS31120
# - sub-OAS31131
# - sub-OAS31142
# - sub-OAS31147
# - sub-OAS31148
# - sub-OAS31176
# - sub-OAS31180
# - sub-OAS31184
# - sub-OAS31193
# - sub-OAS31195
# - sub-OAS31199
# - sub-OAS31202
# - sub-OAS31210
# - sub-OAS31211
# - sub-OAS31219
# - sub-OAS31224
# - sub-OAS31228
# - sub-OAS31234
# - sub-OAS31236
# - sub-OAS31238
# - sub-OAS31240
# - sub-OAS31241
# - sub-OAS31242
# - sub-OAS31243
# - sub-OAS31248
# - sub-OAS31249
# - sub-OAS31259
# - sub-OAS31260
# - sub-OAS31261
# - sub-OAS31265
# - sub-OAS31267
# - sub-OAS31271
# - sub-OAS31273
# - sub-OAS31274
# - sub-OAS31276
# - sub-OAS31282
# - sub-OAS31284
# - sub-OAS31285
# - sub-OAS31294
# - sub-OAS31297
# - sub-OAS31299
# - sub-OAS31302
# - sub-OAS31315
# - sub-OAS31319
# - sub-OAS31320
# - sub-OAS31324
# - sub-OAS31329
# - sub-OAS31331
# - sub-OAS31333
# - sub-OAS31345
# - sub-OAS31349
# - sub-OAS31366
# - sub-OAS31367
# - sub-OAS31369
# - sub-OAS31374
# - sub-OAS31381
# - sub-OAS31385
# - sub-OAS31391
# - sub-OAS31393
# - sub-OAS31397
# - sub-OAS31401
# - sub-OAS31407
# - sub-OAS31408
# - sub-OAS31409
# - sub-OAS31427
# - sub-OAS31431
# - sub-OAS31433
# - sub-OAS31437
# - sub-OAS31449
# - sub-OAS31459
# - sub-OAS31472
# - sub-ON01016
# - sub-ON02747
# - sub-ON03748
# - sub-ON04111
# - sub-ON05258
# - sub-ON06421
# - sub-ON08710
# - sub-ON08760
# - sub-ON08792
# - sub-ON09474
# - sub-ON09540
# - sub-ON09681
# - sub-ON09766
# - sub-ON11411
# - sub-ON13545
# - sub-ON17159
# - sub-ON18047
# - sub-ON21959
# - sub-ON22299
# - sub-ON22662
# - sub-ON22671
# - sub-ON23776
# - sub-ON23897
# - sub-ON25939
# - sub-ON26309
# - sub-ON30535
# - sub-ON31551
# - sub-ON33159
# - sub-ON33221
# - sub-ON34754
# - sub-ON34766
# - sub-ON35773
# - sub-ON39099
# - sub-ON39384
# - sub-ON40397
# - sub-ON40757
# - sub-ON41090
# - sub-ON41606
# - sub-ON43210
# - sub-ON43585
# - sub-ON44262
# - sub-ON48555
# - sub-ON48925
# - sub-ON50636
# - sub-ON51005
# - sub-ON51111
# - sub-ON52083
# - sub-ON52220
# - sub-ON52662
# - sub-ON52733
# - sub-ON55820
# - sub-ON56250
# - sub-ON59735
# - sub-ON61087
# - sub-ON61373
# - sub-ON62200
# - sub-ON62592
# - sub-ON63221
# - sub-ON63335
# - sub-ON63704
# - sub-ON64410
# - sub-ON65403
# - sub-ON66199
# - sub-ON66401
# - sub-ON66452
# - sub-ON67121
# - sub-ON69092
# - sub-ON71932
# - sub-ON72082
# - sub-ON74065
# - sub-ON75100
# - sub-ON75413
# - sub-ON76144
# - sub-ON76320
# - sub-ON76525
# - sub-ON77753
# - sub-ON79309
# - sub-ON80038
# - sub-ON82386
# - sub-ON83320
# - sub-ON84201
# - sub-ON84896
# - sub-ON87092
# - sub-ON87313
# - sub-ON87362
# - sub-ON87550
# - sub-ON87616
# - sub-ON87631
# - sub-ON87655
# - sub-ON87777
# - sub-ON88512
# - sub-ON88555
# - sub-ON88700
# - sub-ON88753
# - sub-ON88762
# - sub-ON89474
# - sub-ON91906
# - sub-ON92220
# - sub-ON93016
# - sub-ON93503
# - sub-ON94856
# - sub-ON95520
# - sub-ON96240
# - sub-ON96252
# - sub-ON96440
# - sub-ON96510
# - sub-ON96555
# - sub-ON96565
# - sub-ON96602
# - sub-ON97252
# - sub-ON98175
# - sub-ON98362
# - sub-ON98602
# - sub-ON98664
# - sub-ON98745
# - sub-ON98806
# - sub-ON98826
# - sub-ON99633
# - sub-ON99943
# Total rows used : 9,068
#   TRAIN : 6,617
#   VAL   : 992
#   TEST  : 1,459

# %%
# ------------------------------------------------------------
# Build BALANCED TEST set (≤4 samples per (age, sex, modality))
# ------------------------------------------------------------
def balance_test_set(df: pd.DataFrame, max_per_combo: int = 4) -> pd.DataFrame:
    """Return a balanced test set with at most `max_per_combo` rows for each (age, sex, modality)."""
    grouped = df.groupby(['age', 'sex', 'modality'], group_keys=False)
    return (grouped.apply(lambda g: g.sample(n=min(max_per_combo, len(g)), random_state=RANDOM_STATE))
                  .reset_index(drop=True))

df_test_balanced = balance_test_set(df_test)
print(f'Original TEST size : {len(df_test):,}')
print(f'Balanced TEST size : {len(df_test_balanced):,}')
# Out:
# Original TEST size : 1,459
# Balanced TEST size : 997

# %%
# ------------------------------------------------------------
# Compute sample weights for TRAIN / VAL / TEST
# ------------------------------------------------------------
def add_sample_weights(df: pd.DataFrame) -> pd.DataFrame:
    """Add inverse-frequency sample weights per (age, modality, sex)."""
    df = df.copy()
    df['age_bin'] = df['age'].astype(int)
    freq = df.groupby(['age_bin','modality','sex']).size().rename('freq')
    df = df.join(freq, on=['age_bin','modality','sex'])
    df['sample_weight'] = 1.0 / df['freq']
    df['sample_weight'] /= df['sample_weight'].sum()
    return df.drop(columns=['age_bin','freq'])

# apply to each split
df_train = add_sample_weights(df_train)
df_val   = add_sample_weights(df_val)   if not df_val.empty else df_val
df_test  = add_sample_weights(df_test)
df_test_balanced = add_sample_weights(df_test_balanced)

# %%
# ------------------------------------------------------------
# Build MINIMAL tuning subsets (male, t1, age 30-40 by default)
# ------------------------------------------------------------
df_train_min = df_train.query(
    'sex == @SUBSET_SEX and modality == @SUBSET_MODALITY and @SUBSET_AGE_MIN <= age <= @SUBSET_AGE_MAX'
).copy()
df_val_min = (df_val.query(
    'sex == @SUBSET_SEX and modality == @SUBSET_MODALITY and @SUBSET_AGE_MIN <= age <= @SUBSET_AGE_MAX'
).copy() if not df_val.empty else df_val.copy())
df_test_min = df_test.query(
    'sex == @SUBSET_SEX and modality == @SUBSET_MODALITY and @SUBSET_AGE_MIN <= age <= @SUBSET_AGE_MAX'
).copy()

# Re-compute weights inside the minimal subsets
df_train_min = add_sample_weights(df_train_min) if not df_train_min.empty else df_train_min
df_val_min   = add_sample_weights(df_val_min)   if not df_val_min.empty else df_val_min
df_test_min  = add_sample_weights(df_test_min)  if not df_test_min.empty else df_test_min

print(f"Minimal subset sizes – TRAIN: {len(df_train_min)}, VAL: {len(df_val_min)}, TEST: {len(df_test_min)}")
# Out:
# Minimal subset sizes – TRAIN: 285, VAL: 51, TEST: 79

# %%
# ------------------------------------------------------------
# Build ADDITIONAL scenario subsets (unchanged)
# ------------------------------------------------------------
# ... (content identical to previous version) ...

# %%
# ------------------------------------------------------------
# Save split to CSV files (full & minimal subsets)
# ------------------------------------------------------------
df_train.to_csv(LABEL_DIR / 'train.csv', index=False)
df_val.to_csv(LABEL_DIR / 'val.csv',   index=False)
df_test.to_csv(LABEL_DIR / 'test.csv', index=False)
df_test_balanced.to_csv(LABEL_DIR / 'test_balanced.csv', index=False)

# --- minimal subset CSVs ---------------------------------------------------
df_train_min.to_csv(LABEL_DIR / 'train_t1_30_40.csv', index=False)
df_val_min.to_csv(LABEL_DIR / 'val_t1_30_40.csv',     index=False)
df_test_min.to_csv(LABEL_DIR / 'test_t1_30_40.csv',   index=False)

# --- additional scenario CSVs (unchanged) ---------------------------------
# ... (content identical to previous version) ...

print(f'Saved all files to {LABEL_DIR.resolve()}')
print('\nAdditional file created: test_balanced.csv (≤4 per (age, sex, modality))')
# Out:
# Saved all files to /Users/andrasjoos/Documents/AI_masters/Thesis/thesis_project/brain_age_pred/data/labels
#
# Additional file created: test_balanced.csv (≤4 per (age, sex, modality))

# %% [markdown]
# ### Train Set Analysis

# %%
quick_plots(df_train, 'TRAIN set')
train_subset = coverage_report(df_train, 'TRAIN coverage')
train_subset.to_csv(LABEL_DIR / 'train_one_per_combo.csv', index=False)
plot_count_heatmap(df_train, 'TRAIN set')
print(f'Saved train_one_per_combo.csv to {LABEL_DIR.resolve()}')
# Out:
# ### TRAIN set – shape: (6617, 8)
#      subject_id                                         image_path     sex  \
# 0      sub-3660  OpenNeuro/DallasLifeSpan/sub-3660_ses-wave1_ac...  female
# 1  sub-OAS31234   OASIS/OASIS3/sub-OAS31234_sess-d0209_T1w.nii.npy  female
# 2       sub-349  OpenNeuro/DallasLifeSpan/sub-349_ses-wave1_acq...  female
# 3       sub-891  OpenNeuro/DallasLifeSpan/sub-891_ses-wave1_acq...    male
# 4  sub-CC410251                    CamCAN/sub-CC410251_T2w.nii.npy  female
#
#    age modality          dataset 5_year_age_bin  sample_weight
# 0   63       t1  dallas_lifespan          60-64       0.000082
# 1   48       t1           oasis3          45-49       0.000127
# 2   76       t2  dallas_lifespan          75-79       0.000255
# 3   26       t1  dallas_lifespan          25-29       0.000047
# 4   53       t2           camcan          50-54       0.000350
# === TRAIN coverage ===
# Expected combinations : 366
# Observed combinations : 357
# Missing combinations  : 9
#    age     sex modality
# 0   20  female    flair
# 1   34    male    flair
# 2   40  female    flair
# 3   41    male    flair
# 4   44  female    flair
# 5   45    male    flair
# 6   52    male    flair
# 7   53    male    flair
# 8   80  female    flair
# Saved train_one_per_combo.csv to /Users/andrasjoos/Documents/AI_masters/Thesis/thesis_project/brain_age_pred/data/labels

# %% [markdown]
# ### Validation Set Analysis

# %%
if not df_val.empty:
    quick_plots(df_val, 'VAL set')
    val_subset = coverage_report(df_val, 'VAL coverage')
    val_subset.to_csv(LABEL_DIR / 'val_one_per_combo.csv', index=False)
    plot_count_heatmap(df_val, 'VAL set')
    print(f'Saved val_one_per_combo.csv to {LABEL_DIR.resolve()}')
else:
    print('VAL set is empty – no analysis performed.')
# Out:
# ### VAL set – shape: (992, 8)
#     subject_id                                         image_path     sex  \
# 0  sub-ON52083  NIMH_RV/sub-ON52083_ses-01_acq-2dADNI2_rec-SCI...  female
# 1  sub-ON96252  NIMH_RV/sub-ON96252_ses-01_acq-2dADNI2_rec-SCI...  female
# 2  sub-ON52083  NIMH_RV/sub-ON52083_ses-01_acq-3dCUBE_rec-SCIC...  female
# 3  sub-ON79309  NIMH_RV/sub-ON79309_ses-01_acq-3dCUBE_rec-SCIC...  female
# 4  sub-ON92220  NIMH_RV/sub-ON92220_ses-01_acq-2dADNI2_rec-SCI...  female
#
#    age modality  dataset 5_year_age_bin  sample_weight
# 0   21    flair  nimh_rv          20-24       0.001068
# 1   21    flair  nimh_rv          20-24       0.001068
# 2   21    flair  nimh_rv          20-24       0.001068
# 3   22    flair  nimh_rv          20-24       0.001068
# 4   22    flair  nimh_rv          20-24       0.001068
# === VAL coverage ===
# Expected combinations : 366
# Observed combinations : 312
# Missing combinations  : 54
#     age     sex modality
# 0    20  female    flair
# 1    20  female       t2
# 2    25    male    flair
# 3    28    male    flair
# 4    29  female       t2
# 5    30  female    flair
# 6    30    male    flair
# 7    35  female    flair
# 8    36    male    flair
# 9    38  female    flair
# 10   38  female       t2
# 11   38    male    flair
# 12   38    male       t2
# 13   39    male    flair
# 14   40  female       t2
# 15   41    male    flair
# 16   41    male       t2
# 17   42  female    flair
# 18   42    male    flair
# 19   43    male    flair
# 20   45    male    flair
# 21   46  female    flair
# 22   48    male    flair
# 23   49  female    flair
# 24   49    male    flair
# 25   51    male    flair
# 26   52    male    flair
# 27   53  female    flair
# 28   53    male    flair
# 29   54    male    flair
# 30   56    male    flair
# 31   57  female    flair
# 32   57    male    flair
# 33   58  female    flair
# 34   58    male    flair
# 35   61    male    flair
# 36   62    male    flair
# 37   64  female    flair
# 38   64  female       t2
# 39   64    male    flair
# 40   69    male    flair
# 41   73    male    flair
# 42   74    male    flair
# 43   75    male    flair
# 44   76  female    flair
# 45   77    male       t2
# 46   78  female    flair
# 47   79    male    flair
# 48   80  female    flair
# 49   80  female       t1
# 50   80  female       t2
# 51   80    male    flair
# 52   80    male       t1
# 53   80    male       t2
# Saved val_one_per_combo.csv to /Users/andrasjoos/Documents/AI_masters/Thesis/thesis_project/brain_age_pred/data/labels

# %% [markdown]
# ### Test Set Analysis

# %%
# quick_plots(df_test, 'TEST set (unbalanced)')
quick_plots(df_test_balanced, 'TEST_BALANCED set')
test_subset = coverage_report(df_test_balanced, 'TEST_BALANCED coverage')
test_subset.to_csv(LABEL_DIR / 'test_balanced.csv', index=False)
plot_count_heatmap(df_test_balanced, 'TEST set')
print(f'Saved test_balanced_one_per_combo.csv to {LABEL_DIR.resolve()}')
# Out:
# ### TEST_BALANCED set – shape: (997, 8)
#   subject_id                                       image_path     sex  age  \
# 0    sub-085  OpenNeuro/BoldVariability/sub-085_FLAIR.nii.npy  female   20
# 1    sub-093  OpenNeuro/BoldVariability/sub-093_FLAIR.nii.npy  female   20
# 2    sub-083  OpenNeuro/BoldVariability/sub-083_FLAIR.nii.npy  female   20
# 3    sub-091  OpenNeuro/BoldVariability/sub-091_FLAIR.nii.npy  female   20
# 4    sub-083    OpenNeuro/BoldVariability/sub-083_T1w.nii.npy  female   20
#
#   modality  dataset 5_year_age_bin  sample_weight
# 0    flair  boldvar          20-24       0.000774
# 1    flair  boldvar          20-24       0.000774
# 2    flair  boldvar          20-24       0.000774
# 3    flair  boldvar          20-24       0.000774
# 4       t1  boldvar          20-24       0.000774
# === TEST_BALANCED coverage ===
# Expected combinations : 366
# Observed combinations : 323
# Missing combinations  : 43
#     age     sex modality
# 0    20    male    flair
# 1    22    male    flair
# 2    23  female    flair
# 3    26  female    flair
# 4    27    male    flair
# 5    29  female    flair
# 6    29    male    flair
# 7    32  female    flair
# 8    34  female    flair
# 9    35  female    flair
# 10   36    male    flair
# 11   37    male    flair
# 12   39    male    flair
# 13   41  female    flair
# 14   41    male    flair
# 15   45    male    flair
# 16   46  female    flair
# 17   48    male    flair
# 18   50  female    flair
# 19   51  female    flair
# 20   51    male    flair
# 21   53    male    flair
# 22   55    male    flair
# 23   57    male    flair
# 24   58    male    flair
# 25   61    male    flair
# 26   62    male    flair
# 27   64    male    flair
# 28   66  female    flair
# 29   67    male    flair
# 30   67    male       t1
# 31   67    male       t2
# 32   71    male    flair
# 33   72    male    flair
# 34   73    male    flair
# 35   74  female    flair
# 36   75    male    flair
# 37   76  female    flair
# 38   77    male       t2
# 39   78  female    flair
# 40   80    male    flair
# 41   80    male       t1
# 42   80    male       t2
# Saved test_balanced_one_per_combo.csv to /Users/andrasjoos/Documents/AI_masters/Thesis/thesis_project/brain_age_pred/data/labels

# %% [markdown]
# ### Full (Train + Val + Test) Dataset Analysis

# %%
quick_plots(df_all, 'FULL dataset (used rows only)')
_ = coverage_report(df_all, 'FULL coverage')
plot_count_heatmap(df_all, 'FULL dataset')
unique_subjects = df_all['subject_id'].unique()
print(f"Number of unique subjects: {len(unique_subjects)}")
# Out:
# ### FULL dataset (used rows only) – shape: (9068, 7)
#          subject_id                       image_path     sex  age modality  \
# 0  IXI002-Guys-0828  IXI/IXI002-Guys-0828-T1.nii.npy  female   36       t1
# 1  IXI002-Guys-0828  IXI/IXI002-Guys-0828-T2.nii.npy  female   36       t2
# 2    IXI012-HH-1211    IXI/IXI012-HH-1211-T1.nii.npy    male   39       t1
# 3    IXI012-HH-1211    IXI/IXI012-HH-1211-T2.nii.npy    male   39       t2
# 4    IXI013-HH-1212    IXI/IXI013-HH-1212-T1.nii.npy    male   47       t1
#
#   dataset 5_year_age_bin
# 0     ixi          35-39
# 1     ixi          35-39
# 2     ixi          35-39
# 3     ixi          35-39
# 4     ixi          45-49
# === FULL coverage ===
# Expected combinations : 366
# Observed combinations : 363
# Missing combinations  : 3
#    age   sex modality
# 0   41  male    flair
# 1   45  male    flair
# 2   53  male    flair
# Number of unique subjects: 5659
